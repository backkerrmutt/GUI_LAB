# %% [markdown]
# code บางส่วน

# %% [markdown]
# function

# %%
def print_lyrics():
    print("I'm a lumberjack, and I'm okay.")
    print('I sleep all night and I work all day.')


def repeat_lyrics():
    print_lyrics()
    print_lyrics()

repeat_lyrics()
# Out:
# {'csev': 2, 'cwen': 2, 'zqian': 1}

# %% [markdown]
# Version 3 แก้ไขโปรแกรมต่อไปนี้ ให้สามารถรับคำสั่ง add , show , หรือ exits ให้อยู่ในรูปของfunction
# เก็บข้อมูลจาก user ด้วย list เช่น todo=[]
# เมื่อรับ ข้อความ add ให้การเพิ่มข้อมูลเข้าไป
# เมื่อรับข้อความ show ให้แสดงค่าที่เก็บใน list ทั้งหมด
# เมื่อรับข้อความ exits ให้ทำการออกจากโปรแกรม

# %% [markdown]
# จงเขียนโปรแกรมด้วยหลักการฟังค์ชัน การหาอัตราจำนวนประชากรของหลักการ fibonacci number
# เดือน 0 จะมีประชากรหญิง เกิดขึ้น 1
# เดือน 1 จะมีประชากรหญิง เกิดขึ้น 1
# เดือน 2 จะมีประชากรหญิง เกิดขึ้น 2
# เดือน 3 จะมีประชากรหญิง เกิดขึ้น 3
# เดือน 4 จะมีประชากรหญิง เกิดขึ้น 5
# เดือน 5 จะมีประชากรหญิง เกิดขึ้น 8
# เดือน 6 จะมีประชากรหญิง เกิดขึ้น 13
#
# จะต้องสามารถ ทดสอบผ่านฟังค์ชัน testFib(n)

# %%
def fib(n):





def testFib(n):
  for i in range(n+1):
    printf('popultion of',i,'=',fib(i))

# %% [markdown]
# เขียน recursive function ของ factorial พร้อมทั้งฟังค์ชันทดสอบ

# %% [markdown]
# พิเศษ
#
# จงนำข้อมูลชื่อตัวการ์ตูน และชนิดสัตว์ที่ตัวการ์ตูนนั้นเป็น มาสรุปว่า สัตว์ชนิดต่าง ๆ มีชื่อตัวการ์ตูนอะไรบ้าง โดยให้แสดงลำดับของ
# ชนิดสัตว์ และลำดับของชื่อตัวการ์ตูนตามลำดับก่อนหลังที่อ่านจากข้อมูลขาเข้า
#
#
# **ข้อมูลนำเข้า**
# รายการของชื่อตัวการ์ตูนและชนิดของสัตว์คั่นด้วยช่องว่าง บรรทัดละหนึ่งตัว
# บรรทัดสุดท้ายเป็นตัวอักษร q
#
# **ข้อมูลส่งออก**
# ชนิดของสัตว์ ตามด้วยรายการของชื่อตัวการ์ตูนที่เป็นสัตว์ชนิดนี้ บรรทัดละชนิด
# โดยให้แสดงลำดับของชนิดสัตว์ และลำดับของชื่อตัวการ์ตูนตามลำดับก่อนหลังที่อ่านจากข้อมูลขาเข้า
#
# ![Screenshot 2567-02-29 at 09.57.49.png](data:image/png;base64,...)
